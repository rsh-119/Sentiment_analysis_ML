# %%
pip install transformers torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-5.12.1-py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 8.9 MB/s eta 0:00:0000:0100:01
# Collecting torch
#   Downloading torch-2.12.1-cp310-cp310-manylinux_2_28_x86_64.whl (532.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.1/532.1 MB 6.0 MB/s eta 0:00:0000:0100:01
# Collecting typer
#   Downloading typer-0.26.7-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 KB 17.5 MB/s eta 0:00:00
# Collecting huggingface-hub<2.0,>=1.5.0
#   Downloading huggingface_hub-1.20.1-py3-none-any.whl (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 KB 17.6 MB/s eta 0:00:0000:01
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (516 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 KB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/rsh/.local/lib/python3.10/site-packages (from transformers) (26.2)
# Requirement already satisfied: numpy>=1.17 in /home/rsh/.local/lib/python3.10/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: tqdm>=4.60 in /home/rsh/.local/lib/python3.10/site-packages (from transformers) (4.68.2)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 16.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: regex>=2025.10.22 in /home/rsh/.local/lib/python3.10/site-packages (from transformers) (2026.5.9)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 18.1 MB/s eta 0:00:00a 0:00:01
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 24.3 MB/s eta 0:00:00
# Collecting triton==3.7.1
#   Downloading triton-3.7.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (197.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 MB 6.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools<82 in /usr/lib/python3/dist-packages (from torch) (59.6.0)
# Collecting nvidia-cusparselt-cu13==0.8.1
#   Downloading nvidia_cusparselt_cu13-0.8.1-py3-none-manylinux2014_x86_64.whl (170.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2
#   Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Collecting fsspec>=0.8.5
#   Downloading fsspec-2026.6.0-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.9/203.9 KB 13.1 MB/s eta 0:00:00
# Collecting networkx>=2.5.1
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cudnn-cu13==9.20.0.48
#   Downloading nvidia_cudnn_cu13-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl (366.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 1.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/rsh/.local/lib/python3.10/site-packages (from torch) (4.15.0)
# Collecting nvidia-nccl-cu13==2.29.7
#   Downloading nvidia_nccl_cu13-2.29.7-py3-none-manylinux_2_18_x86_64.whl (206.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 6.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas<=13.1.1.3,>=13.1.0.3
#   Downloading nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 5.6 MB/s eta 0:00:0000:0100:01
# Collecting cuda-bindings<14,>=13.0.3
#   Downloading cuda_bindings-13.3.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Collecting filelock
#   Downloading filelock-3.29.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 KB 6.8 MB/s eta 0:00:00
# Collecting nvidia-nvshmem-cu13==3.4.5
#   Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 14.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti==13.0.85.*
#   Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 17.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse==12.6.3.3.*
#   Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime==13.0.96.*
#   Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc==13.0.88.*
#   Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 10.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink==13.0.88.*
#   Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 12.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver==12.0.4.66.*
#   Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 7.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft==12.0.0.61.*
#   Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 5.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand==10.4.0.35.*
#   Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 17.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufile==1.15.1.6.*
#   Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.0 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-nvtx==13.0.85.*
#   Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 KB 25.5 MB/s eta 0:00:00
# Collecting cuda-pathfinder>=1.4.2
#   Downloading cuda_pathfinder-1.5.5-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 KB 9.7 MB/s eta 0:00:00
# Collecting click>=8.4.0
#   Downloading click-8.4.1-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 KB 20.2 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.5.1
#   Downloading hf_xet-1.5.1-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 23.1 MB/s eta 0:00:00a 0:00:01
# Collecting typer
#   Downloading typer-0.25.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 KB 8.1 MB/s eta 0:00:00
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 10.5 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 27.0 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: rich>=13.8.0 in /home/rsh/.local/lib/python3.10/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch) (2.0.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2020.6.20)
# Collecting anyio
#   Downloading anyio-4.14.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 KB 22.7 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/rsh/.local/lib/python3.10/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/rsh/.local/lib/python3.10/site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/rsh/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/rsh/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# Installing collected packages: nvidia-cusparselt-cu13, mpmath, cuda-toolkit, triton, sympy, shellingham, safetensors, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, networkx, jinja2, hf-xet, h11, fsspec, filelock, cuda-pathfinder, click, annotated-doc, nvidia-cusparse, nvidia-cufft, nvidia-cublas, httpcore, cuda-bindings, anyio, typer, nvidia-cusolver, nvidia-cudnn-cu13, httpx, huggingface-hub, torch, tokenizers, transformers
# Successfully installed annotated-doc-0.0.4 anyio-4.14.0 click-8.4.1 cuda-bindings-13.3.1 cuda-pathfinder-1.5.5 cuda-toolkit-13.0.2 filelock-3.29.4 fsspec-2026.6.0 h11-0.16.0 hf-xet-1.5.1 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.20.1 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-13.1.1.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.20.0.48 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.1 nvidia-nccl-cu13-2.29.7 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 safetensors-0.8.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.12.1 transformers-5.12.1 triton-3.7.1 typer-0.25.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import transformers
import torch

print(transformers.__version__)
print(torch.__version__)
# Out:
# 5.12.1
# 2.12.1+cu130

# %%
import transformers
print(transformers.__version__)
print(transformers.__file__)
# Out:
# 5.12.1
# /home/rsh/.local/lib/python3.10/site-packages/transformers/__init__.py

# %%
from transformers.pipelines import pipeline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from transformers.pipelines import pipeline
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/__init__.py:27
#      25 from ..dynamic_module_utils import get_class_from_dynamic_module
#      26 from ..feature_extraction_utils import FeatureExtractionMixin
# ---> 27 from ..image_processing_utils import BaseImageProcessor
#      28 from ..models.auto.configuration_auto import AutoConfig
#      29 from ..models.auto.feature_extraction_auto import FEATURE_EXTRACTOR_MAPPING, AutoFeatureExtractor
#
# File ~/.local/lib/python3.10/site-packages/transformers/image_processing_utils.py:24
#      21 import numpy as np
#      22 from huggingface_hub.dataclasses import validate_typed_dict
# ---> 24 from .image_processing_base import BatchFeature, ImageProcessingMixin
#      25 from .image_transforms import center_crop, normalize, rescale
#      26 from .image_utils import (
#      27     ChannelDimension,
#      28     ImageInput,
#    (...)
#      32     validate_preprocess_arguments,
#      33 )
#
# File ~/.local/lib/python3.10/site-packages/transformers/image_processing_base.py:25
#      23 from .dynamic_module_utils import custom_object_save
#      24 from .feature_extraction_utils import BatchFeature as BaseBatchFeature
# ---> 25 from .image_utils import is_valid_image, load_image
#      26 from .utils import (
#      27     IMAGE_PROCESSOR_NAME,
#      28     PROCESSOR_NAME,
#    (...)
#      32     safe_load_json_file,
#      33 )
#      34 from .utils.hub import cached_file, hf_api
#
# File ~/.local/lib/python3.10/site-packages/transformers/image_utils.py:51
#      48     import PIL.Image
#      49     import PIL.ImageOps
# ---> 51     PILImageResampling = PIL.Image.Resampling
#      53 if is_torchvision_available():
#      54     from torchvision.io import ImageReadMode, decode_image
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:65, in __getattr__(name)
#      58     warnings.warn(
#      59         "Image categories are deprecated and will be removed in Pillow 10 "
#      60         "(2023-07-01). Use is_animated instead.",
#      61         DeprecationWarning,
#      62         stacklevel=2,
#      63     )
#      64     return categories[name]
# ---> 65 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'PIL.Image' has no attribute 'Resampling'

# %%
from transformers import pipeline

classifier = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

print(classifier("This movie is worth it"))
print(classifier("This movie is not worth it"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2262, in _LazyModule.__getattr__(self, name)
#    2261 try:
# -> 2262     module = self._get_module(self._class_to_module[name])
#    2263     value = getattr(module, name)
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2496, in _LazyModule._get_module(self, module_name)
#    2495 except Exception as e:
# -> 2496     raise e
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2494, in _LazyModule._get_module(self, module_name)
#    2493 try:
# -> 2494     return importlib.import_module("." + module_name, self.__name__)
#    2495 except Exception as e:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/__init__.py:27
#      26 from ..feature_extraction_utils import FeatureExtractionMixin
# ---> 27 from ..image_processing_utils import BaseImageProcessor
#      28 from ..models.auto.configuration_auto import AutoConfig
#
# File ~/.local/lib/python3.10/site-packages/transformers/image_processing_utils.py:24
#      22 from huggingface_hub.dataclasses import validate_typed_dict
# ---> 24 from .image_processing_base import BatchFeature, ImageProcessingMixin
#      25 from .image_transforms import center_crop, normalize, rescale
#
# File ~/.local/lib/python3.10/site-packages/transformers/image_processing_base.py:25
#      24 from .feature_extraction_utils import BatchFeature as BaseBatchFeature
# ---> 25 from .image_utils import is_valid_image, load_image
#      26 from .utils import (
#      27     IMAGE_PROCESSOR_NAME,
#      28     PROCESSOR_NAME,
#    (...)
#      32     safe_load_json_file,
#      33 )
#
# File ~/.local/lib/python3.10/site-packages/transformers/image_utils.py:51
#      49     import PIL.ImageOps
# ---> 51     PILImageResampling = PIL.Image.Resampling
#      53 if is_torchvision_available():
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:65, in __getattr__(name)
#      64     return categories[name]
# ---> 65 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'PIL.Image' has no attribute 'Resampling'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transformers import pipeline
#       3 classifier = pipeline(
#       4     "sentiment-analysis",
#       5     model="distilbert-base-uncased-finetuned-sst-2-english"
#       6 )
#       8 print(classifier("This movie is worth it"))
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2350, in _LazyModule.__getattr__(self, name)
#    2346                     raise ModuleNotFoundError(
#    2347                         f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2348                     ) from e
#    2349         else:
# -> 2350             raise ModuleNotFoundError(
#    2351                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2352             ) from e
#    2354 elif name in self._modules:
#    2355     try:
#
# ModuleNotFoundError: Could not import module 'pipeline'. Are this object's requirements defined correctly?
