# %%
# !pip install nltk
# !pip install pandas
# !pip install numpy
# !pip install bs4
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/rsh/.local/lib/python3.10/site-packages (3.9.4)
# Requirement already satisfied: tqdm in /home/rsh/.local/lib/python3.10/site-packages (from nltk) (4.68.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/rsh/.local/lib/python3.10/site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: joblib in /home/rsh/.local/lib/python3.10/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/rsh/.local/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/rsh/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /home/rsh/.local/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/rsh/.local/lib/python3.10/site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/rsh/.local/lib/python3.10/site-packages (2.2.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in /home/rsh/.local/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /home/rsh/.local/lib/python3.10/site-packages (from bs4) (4.15.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/rsh/.local/lib/python3.10/site-packages (from beautifulsoup4->bs4) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/rsh/.local/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.8.4)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp310-cp310-manylinux_2_27_x86_64.whl (572.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.2/572.2 MB 3.6 MB/s eta 0:00:0000:0100:03
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.4-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 3.7 MB/s eta 0:00:0000:0100:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting google_pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 4.8 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-2.2.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.5/152.5 KB 8.6 MB/s eta 0:00:00
# Collecting h5py<3.15.0,>=3.11.0
#   Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 5.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: packaging in /home/rsh/.local/lib/python3.10/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorflow) (2.25.1)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.81.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 5.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting protobuf<8.0.0,>=6.31.1
#   Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl (327 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.1/327.1 KB 6.0 MB/s eta 0:00:00a 0:00:01
# Collecting keras>=3.12.0
#   Downloading keras-3.12.2-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/rsh/.local/lib/python3.10/site-packages (from tensorflow) (4.15.0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 KB 6.2 MB/s eta 0:00:00
# Collecting opt_einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 7.0 MB/s eta 0:00:00
# Collecting flatbuffers>=25.9.23
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 5.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.26.0 in /home/rsh/.local/lib/python3.10/site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting namex
#   Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting optree
#   Downloading optree-0.19.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (425 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.5/425.5 KB 5.4 MB/s eta 0:00:0000:0100:01
# Collecting rich
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 KB 6.4 MB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 KB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/rsh/.local/lib/python3.10/site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, termcolor, protobuf, optree, opt_einsum, ml_dtypes, mdurl, h5py, grpcio, google_pasta, gast, astunparse, absl-py, markdown-it-py, rich, keras, tensorflow
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.81.1 h5py-3.14.0 keras-3.12.2 libclang-18.1.1 markdown-it-py-4.2.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.1 protobuf-7.35.1 rich-15.0.0 tensorflow-2.21.0 termcolor-3.3.0 wrapt-2.2.1

# %%
import nltk
import numpy as np 
import pandas as pd 
import tensorflow as tf
import bs4 as beautifulSoap
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781608724.372144   94931 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781608724.374344   94931 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781608724.413185   94931 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781608725.277305   94931 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781608725.277647   94931 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# [nltk_data] Downloading package stopwords to /home/rsh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/rsh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = pd.read_csv("/home/rsh/Desktop/projects /IMDB Dataset.csv")

# %%
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ### TEXT Preprocessing

# %%
from nltk.tokenize import word_tokenize 
import string 
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /home/rsh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/rsh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True
